# %%
import requests
import os
from bs4 import BeautifulSoup

# %%
os.chdir('/Users/intothelight/nycdatascience/deepwaterlearning.github.io/project_02')
os.getcwd()
# Out:
# '/Users/intothelight/nycdatascience/deepwaterlearning.github.io/project_02'

# %%
def check_url(url):
    response_code = requests.head(url)
    print(response_code.status_code)
    return response_code.status_code < 400

# %%
#import requests 
#payload = { 'inUserName': 'username', 'inUserPass': 'password' } 
#with requests.Session() as s:
#	p = s.post('URL_FOR_LOGIN', data=payload) 
#	print p.text
#	r = s.get('A protected web page url') 
#	print r.text 
#	# ...
scanner_url = "http://urlquery.net/"
website_url = "http://youporn.com/"
if check_url(scanner_url):
    print("Scanner is up")
else:
    print("Scanner not available")
    
if check_url(website_url):
    print("Target site is up")
else:
    print("Target site not available")
# Out:
# 200
# Scanner is up
# 301
# Target site is up

# %%
session = requests.session()
payload = {"url": website_url}
print(payload)
print("--------------------")
r = requests.post(scanner_url,allow_redirects=True,data=payload)
print(r.history)
print("--------------------")
print(r.text)
# Out:
# {'url': 'http://youporn.com/'}
# --------------------
# []
# --------------------
#
# <!DOCTYPE html>
# <html>
# <head>
# 	<meta http-equiv="content-type" content="text/html; charset=utf-8" />
#
#
# 	<link rel="stylesheet" href="main.css" media="screen" />
# 	<link type="text/css" href="jquery-ui-1.9.2.custom.css" rel="stylesheet" />
# 	<script type="text/javascript" src="./javascript/jquery-1.8.3.js"></script>
# 	<script type="text/javascript" src="./javascript/jquery-ui-1.9.2.custom.min.js"></script>
#
#   <style type="text/css">
#     .ui-dialog-buttonpane { text-align: right; }
#   </style>
#
# 	<title>urlquery.net - Free URL scanner</title>
#
# 	<meta name="description" content="urlQuery.net is a service for scanning URLs and detecting web-based malware. Providing detailed information about the browsers activity while visiting an site." />
# 	<meta name="keywords" content="" />
#
#
#
# 	<script type="text/javascript">
# 		$(document).ready(function()
# 		{
# 			$(function()
# ...

# %%
webpage = BeautifulSoup(r.text,'html.parser')
print(webpage.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="main.css" media="screen" rel="stylesheet"/>
#   <link href="jquery-ui-1.9.2.custom.css" rel="stylesheet" type="text/css"/>
#   <script src="./javascript/jquery-1.8.3.js" type="text/javascript">
#   </script>
#   <script src="./javascript/jquery-ui-1.9.2.custom.min.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    .ui-dialog-buttonpane { text-align: right; }
#   </style>
#   <title>
#    urlquery.net - Free URL scanner
#   </title>
#   <meta content="urlQuery.net is a service for scanning URLs and detecting web-based malware. Providing detailed information about the browsers activity while visiting an site." name="description"/>
#   <meta content="" name="keywords"/>
#   <script type="text/javascript">
#    $(document).ready(function()
# 		{
# 			$(function()
# 			{
# 				$( "#accordion" ).accordion({
# 					collapsible: true,
# ...

# %%
r.history
# Out:
# []
